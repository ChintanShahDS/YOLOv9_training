# %% [markdown]
# # How to Train YOLOv9 on a Custom Dataset
# ---
#
# [![Roboflow](https://raw.githubusercontent.com/roboflow-ai/notebooks/main/assets/badges/roboflow-blogpost.svg)](https://blog.roboflow.com/train-yolov9-model/)
# [![GitHub](https://badges.aleen42.com/src/github.svg)](https://github.com/WongKinYiu/yolov9)
# [![YouTube](https://badges.aleen42.com/src/youtube.svg)](https://youtu.be/XHT2c8jT3Bc)
# [![arXiv](https://img.shields.io/badge/arXiv-2402.13616-b31b1b.svg)](https://arxiv.org/pdf/2402.13616.pdf)

# %% [markdown]
# ## Before you start
#
# Let's make sure that we have access to GPU. We can use `nvidia-smi` command to do that. In case of any problems navigate to `Edit` -> `Notebook settings` -> `Hardware accelerator`, set it to `GPU`, and then click `Save`.

# %%
# !nvidia-smi
# Out:
# Sun May  5 12:02:00 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla V100-SXM2-16GB           Off | 00000000:00:04.0 Off |                    0 |
# | N/A   39C    P0              28W / 300W |      0MiB / 16384MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %% [markdown]
# **NOTE:** To make it easier for us to manage datasets, images and models we create a `HOME` constant.

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %% [markdown]
# ## Clone and Install

# %% [markdown]
# **NOTE:** YOLOv9 is very new. At the moment, we recommend using a fork of the main repository. The `detect.py` script contains a bug that prevents inference. This bug is patched in the fork.

# %%
# !git clone https://github.com/SkalskiP/yolov9.git
# %cd yolov9
# !pip install -r requirements.txt -q
# Out:
# Cloning into 'yolov9'...
# remote: Enumerating objects: 325, done.
# remote: Counting objects: 100% (216/216), done.
# remote: Compressing objects: 100% (61/61), done.
# remote: Total 325 (delta 158), reused 155 (delta 155), pack-reused 109
# Receiving objects: 100% (325/325), 2.23 MiB | 14.21 MiB/s, done.
# Resolving deltas: 100% (165/165), done.
# /content/yolov9
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 2.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 5.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 16.6 MB/s eta 0:00:00

# %% [markdown]
# **NOTE:** Let's install the [`roboflow`](https://pypi.org/project/roboflow) package, which we will use to download our dataset from [Roboflow Universe](https://universe.roboflow.com/).

# %%
# !pip install -q roboflow
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.6/74.6 kB 1.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.3/158.3 kB 3.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 12.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 7.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 1.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 1.4 MB/s eta 0:00:00

# %% [markdown]
# ## Download model weights

# %% [markdown]
# **NOTE:** In the YOLOv9 paper, versions `yolov9-s` and `yolov9-m` are also mentioned, but the weights for these models are not yet available in the YOLOv9 [repository](https://github.com/WongKinYiu/yolov9).

# %%
# !wget -P {HOME}/weights -q https://github.com/WongKinYiu/yolov9/releases/download/v0.1/yolov9-c.pt
# !wget -P {HOME}/weights -q https://github.com/WongKinYiu/yolov9/releases/download/v0.1/yolov9-e.pt
# !wget -P {HOME}/weights -q https://github.com/WongKinYiu/yolov9/releases/download/v0.1/gelan-c.pt
# !wget -P {HOME}/weights -q https://github.com/WongKinYiu/yolov9/releases/download/v0.1/gelan-e.pt

# %%
# !ls -la {HOME}/weights
# Out:
# total 402440
# drwxr-xr-x 2 root root      4096 May  5 12:03 .
# drwxr-xr-x 1 root root      4096 May  5 12:03 ..
# -rw-r--r-- 1 root root  51508261 Feb 18 12:36 gelan-c.pt
# -rw-r--r-- 1 root root 117203713 Feb 18 12:36 gelan-e.pt
# -rw-r--r-- 1 root root 103153312 Feb 18 12:36 yolov9-c.pt
# -rw-r--r-- 1 root root 140217688 Feb 18 12:36 yolov9-e.pt

# %% [markdown]
# ## Download example data

# %% [markdown]
# **NOTE:** If you want to run inference using your own file as input, simply upload image to Google Colab and update `SOURCE_IMAGE_PATH` with the path leading to your file.

# %%
# !wget -P {HOME}/data -q https://media.roboflow.com/notebooks/examples/dog.jpeg

# %%
# SOURCE_IMAGE_PATH = f"{HOME}/dog.jpeg"

# %% [markdown]
# ## Detection with pre-trained COCO model

# %% [markdown]
# ### gelan-c

# %%
# !python detect.py --weights {HOME}/weights/gelan-c.pt --conf 0.1 --source {HOME}/data/dog.jpeg --device 0

# %% [markdown]
# **NOTE:** By default, the results of each subsequent inference sessions are saved in `{HOME}/yolov9/runs/detect/`, in directories named `exp`, `exp2`, `exp3`, ... You can override this behavior by using the `--name` parameter.

# %%
# from IPython.display import Image

# Image(filename=f"{HOME}/yolov9/runs/detect/exp/dog.jpeg", width=600)

# %% [markdown]
# ## yolov9-e

# %%
# !python detect.py --weights {HOME}/weights/yolov9-e.pt --conf 0.1 --source {HOME}/data/dog.jpeg --device 0

# %%
# from IPython.display import Image

# Image(filename=f"{HOME}/yolov9/runs/detect/exp2/dog.jpeg", width=600)

# %% [markdown]
# ## Authenticate and Download the Dataset

# %% [markdown]
# **NOTE:** The dataset must be saved inside the `{HOME}/yolov9` directory, otherwise, the training will not succeed.

# %%
# %cd {HOME}/yolov9
# Out:
# /content/yolov9

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pwd
# Out:
# /content/yolov9

# %%
# !cp -r /content/drive/MyDrive/Workspace/numberplate data/

# %% [markdown]
# **NOTE:** In this tutorial, I will use the [football-players-detection](https://universe.roboflow.com/roboflow-jvuqo/football-players-detection-3zvbc) dataset. Feel free to replace it with your dataset in YOLO format or use another dataset available on [Roboflow Universe](https://universe.roboflow.com). Additionally, if you plan to deploy your model to Roboflow after training, make sure you are the owner of the dataset and that no model is associated with the version of the dataset you are going to training on.

# %%
# import roboflow

# roboflow.login()

# rf = roboflow.Roboflow()

# project = rf.workspace("roboflow-jvuqo").project("football-players-detection-3zvbc")
# version = project.version(8)
# dataset = version.download("yolov9")

# %% [markdown]
# ## Train Custom Model

# %%
# !pwd
# Out:
# /content/yolov9

# %%
# %cd {HOME}/yolov9

# !python train.py \
--batch 16 --epochs 25 --img 640 --device 0 --min-items 0 --close-mosaic 15 \
--data ./data/numberplate/numberplate.yaml \
--weights {HOME}/weights/gelan-c.pt \
--cfg models/detect/gelan-c.yaml \
--hyp hyp.scratch-high.yaml
# Out:
# /content/yolov9
# 2024-05-05 12:14:51.496735: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-05 12:14:51.496788: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-05 12:14:51.498220: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-05-05 12:14:52.650056: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# train: weights=/content/weights/gelan-c.pt, cfg=models/detect/gelan-c.yaml, data=./data/numberplate/numberplate.yaml, hyp=hyp.scratch-high.yaml, epochs=25, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=0, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, flat_cos_lr=False, fixed_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, min_items=0, close_mosaic=15, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# YOLOv5 🚀 1e33dbb Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, cls_pw=1.0, dfl=1.5, obj_pw=1.0, iou_t=0.2, anchor_t=5.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.9, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.15, copy_paste=0.3
# ClearML: run 'pip install clearml' to automatically track, visualize and remotely train YOLO 🚀 in ClearML
# Comet: run 'pip install comet_ml' to automatically track and visualize YOLO 🚀 runs in Comet
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# Overriding model.yaml nc=80 with nc=1
#
#                  from  n    params  module                                  arguments
#   0                -1  1      1856  models.common.Conv                      [3, 64, 3, 2]
#   1                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   2                -1  1    212864  models.common.RepNCSPELAN4              [128, 256, 128, 64, 1]
#   3                -1  1    164352  models.common.ADown                     [256, 256]
#   4                -1  1    847616  models.common.RepNCSPELAN4              [256, 512, 256, 128, 1]
#   5                -1  1    656384  models.common.ADown                     [512, 512]
#   6                -1  1   2857472  models.common.RepNCSPELAN4              [512, 512, 512, 256, 1]
#   7                -1  1    656384  models.common.ADown                     [512, 512]
#   8                -1  1   2857472  models.common.RepNCSPELAN4              [512, 512, 512, 256, 1]
#   9                -1  1    656896  models.common.SPPELAN                   [512, 512, 256]
#  10                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  11           [-1, 6]  1         0  models.common.Concat                    [1]
#  12                -1  1   3119616  models.common.RepNCSPELAN4              [1024, 512, 512, 256, 1]
#  13                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  14           [-1, 4]  1         0  models.common.Concat                    [1]
#  15                -1  1    912640  models.common.RepNCSPELAN4              [1024, 256, 256, 128, 1]
#  16                -1  1    164352  models.common.ADown                     [256, 256]
#  17          [-1, 12]  1         0  models.common.Concat                    [1]
#  18                -1  1   2988544  models.common.RepNCSPELAN4              [768, 512, 512, 256, 1]
#  19                -1  1    656384  models.common.ADown                     [512, 512]
#  20           [-1, 9]  1         0  models.common.Concat                    [1]
#  21                -1  1   3119616  models.common.RepNCSPELAN4              [1024, 512, 512, 256, 1]
#  22      [15, 18, 21]  1   5491411  models.yolo.DDetect                     [1, [256, 512, 512]]
# gelan-c summary: 621 layers, 25437843 parameters, 25437827 gradients, 103.2 GFLOPs
#
# Transferred 931/937 items from /content/weights/gelan-c.pt
# AMP: checks passed ✅
# optimizer: SGD(lr=0.01) with parameter groups 154 weight(decay=0.0), 161 weight(decay=0.0005), 160 bias
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# train: Scanning /content/yolov9/data/numberplate/custom.cache... 120 images, 3 backgrounds, 0 corrupt: 100% 120/120 [00:00<?, ?it/s]
# train: WARNING ⚠️ /content/yolov9/data/numberplate/images/20230327_170242.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/yolov9/data/numberplate/images/20230327_170249.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/yolov9/data/numberplate/images/20230327_170259.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/yolov9/data/numberplate/images/20230418_125454.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/yolov9/data/numberplate/images/20230425_163417.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/yolov9/data/numberplate/images/20230515_095931.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/yolov9/data/numberplate/images/20230515_125709.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/yolov9/data/numberplate/images/20230515_131318.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/yolov9/data/numberplate/images/20230620_161305.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/yolov9/data/numberplate/images/20230620_161309.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/yolov9/data/numberplate/images/20230620_161311.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/yolov9/data/numberplate/images/20230620_161316.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/yolov9/data/numberplate/images/20230620_161321.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/yolov9/data/numberplate/images/20230620_161323.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/yolov9/data/numberplate/images/20230620_161329.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/yolov9/data/numberplate/images/20230620_161339.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/yolov9/data/numberplate/images/20230620_161340.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/yolov9/data/numberplate/images/20230620_161342.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/yolov9/data/numberplate/images/20230620_161346.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/yolov9/data/numberplate/images/20230620_161350.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/yolov9/data/numberplate/images/20230620_161351.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/yolov9/data/numberplate/images/20230620_161355.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/yolov9/data/numberplate/images/20230620_161402.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/yolov9/data/numberplate/images/20230622_061634.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/yolov9/data/numberplate/images/20230622_061642.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/yolov9/data/numberplate/images/20230622_152224.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/yolov9/data/numberplate/images/20230622_152225.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/yolov9/data/numberplate/images/20230624_184848.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/yolov9/data/numberplate/images/20230624_184914.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/yolov9/data/numberplate/images/20230624_184921.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/yolov9/data/numberplate/images/20230626_091534.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/yolov9/data/numberplate/images/20230626_091536.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/yolov9/data/numberplate/images/20230626_091543.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/yolov9/data/numberplate/images/20230626_091545.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/yolov9/data/numberplate/images/20230626_091547.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/yolov9/data/numberplate/images/20230626_091550.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/yolov9/data/numberplate/images/20230626_091552.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/yolov9/data/numberplate/images/20230626_091553.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/yolov9/data/numberplate/images/20230626_091555.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/yolov9/data/numberplate/images/20230626_091559.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/yolov9/data/numberplate/images/20230626_091644.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/yolov9/data/numberplate/images/20230626_091650.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/yolov9/data/numberplate/images/20230626_091651.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/yolov9/data/numberplate/images/20230626_091654.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/yolov9/data/numberplate/images/20230626_091657.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/yolov9/data/numberplate/images/20230626_091702.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/yolov9/data/numberplate/images/20230626_091711.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/yolov9/data/numberplate/images/20230626_091713.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/yolov9/data/numberplate/images/20230702_133115.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/yolov9/data/numberplate/images/20230707_133949.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/yolov9/data/numberplate/images/20230707_135450.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/yolov9/data/numberplate/images/20230707_152433.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/yolov9/data/numberplate/images/20230707_152443.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/yolov9/data/numberplate/images/20230707_161708.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/yolov9/data/numberplate/images/20230707_162111.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/yolov9/data/numberplate/images/20230707_162117.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/yolov9/data/numberplate/images/20230707_162119.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/yolov9/data/numberplate/images/20230707_162121.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/yolov9/data/numberplate/images/20240201_165141.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/yolov9/data/numberplate/images/20240201_165149.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/yolov9/data/numberplate/images/20240201_165219.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/yolov9/data/numberplate/images/20240201_165227.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /content/yolov9/data/numberplate/images/20240201_165232.jpg: corrupt JPEG restored and saved
# val: Scanning /content/yolov9/data/numberplate/customtest.cache... 15 images, 2 backgrounds, 0 corrupt: 100% 15/15 [00:00<?, ?it/s]
# val: WARNING ⚠️ /content/yolov9/data/numberplate/images/20230515_133831.jpg: corrupt JPEG restored and saved
# val: WARNING ⚠️ /content/yolov9/data/numberplate/images/20230516_131859.jpg: corrupt JPEG restored and saved
# val: WARNING ⚠️ /content/yolov9/data/numberplate/images/20230620_161335.jpg: corrupt JPEG restored and saved
# val: WARNING ⚠️ /content/yolov9/data/numberplate/images/20230620_161338.jpg: corrupt JPEG restored and saved
# val: WARNING ⚠️ /content/yolov9/data/numberplate/images/20230626_091537.jpg: corrupt JPEG restored and saved
# val: WARNING ⚠️ /content/yolov9/data/numberplate/images/20230626_091541.jpg: corrupt JPEG restored and saved
# val: WARNING ⚠️ /content/yolov9/data/numberplate/images/20230626_091557.jpg: corrupt JPEG restored and saved
# val: WARNING ⚠️ /content/yolov9/data/numberplate/images/20230626_091652.jpg: corrupt JPEG restored and saved
# val: WARNING ⚠️ /content/yolov9/data/numberplate/images/20230626_091708.jpg: corrupt JPEG restored and saved
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# Plotting labels to runs/train/exp5/labels.jpg...
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to runs/train/exp5
# Starting training for 25 epochs...
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        0/24      11.2G      2.061      5.557       1.72         29        640: 100% 8/8 [02:12<00:00, 16.62s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:02<00:00,  2.29s/it]
#                    all         15         35   0.000222     0.0286   0.000115   1.15e-05
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/24      11.2G      1.561      3.744      1.339         43        640: 100% 8/8 [02:00<00:00, 15.01s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  5
0.521
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/24      11.3G      1.023     0.5411     0.9272         11        640: 100% 8/8 [00:27<00:00,  3.50s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.23it/s]
#                    all         15         35      0.961      0.771      0.825      0.518
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/24      11.3G      1.021     0.5229     0.9769         19        640: 100% 8/8 [00:30<00:00,  3.85s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  5.53it/s]
#                    all         15         35      0.872      0.829       0.85      0.527
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/24      11.3G      1.056     0.5282     0.9511         14        640: 100% 8/8 [00:26<00:00,  3.36s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  5.59it/s]
#                    all         15         35      0.905      0.812      0.851      0.521
#
# 25 epochs completed in 0.470 hours.
# Optimizer stripped from runs/train/exp5/weights/last.pt, saved as runs/train/exp5/weights/last_striped.pt, 51.4MB
# Optimizer stripped from runs/train/exp5/weights/best.pt, saved as runs/train/exp5/weights/best_striped.pt, 51.4MB
#
# Validating runs/train/exp5/weights/best.pt...
# Fusing layers...
# gelan-c summary: 467 layers, 25411731 parameters, 0 gradients, 102.5 GFLOPs
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  2.01it/s]
#                    all         15         35      0.872      0.829       0.85      0.524
# Results saved to runs/train/exp5

# %% [markdown]
# ## Examine Training Results

# %% [markdown]
# **NOTE:** By default, the results of each subsequent training sessions are saved in `{HOME}/yolov9/runs/train/`, in directories named `exp`, `exp2`, `exp3`, ... You can override this behavior by using the `--name` parameter.

# %%
# !ls {HOME}/yolov9/runs/train/exp5/
# Out:
# confusion_matrix.png				     opt.yaml	   train_batch0.jpg
# events.out.tfevents.1714909002.e90bf5d46fbe.13568.0  P_curve.png   train_batch1.jpg
# F1_curve.png					     PR_curve.png  train_batch2.jpg
# hyp.yaml					     R_curve.png   val_batch0_labels.jpg
# labels_correlogram.jpg				     results.csv   val_batch0_pred.jpg
# labels.jpg					     results.png   weights

# %%
from IPython.display import Image

Image(filename=f"{HOME}/yolov9/runs/train/exp5/results.png", width=1000)

# %%
from IPython.display import Image

Image(filename=f"{HOME}/yolov9/runs/train/exp5/confusion_matrix.png", width=1000)

# %%
from IPython.display import Image

Image(filename=f"{HOME}/yolov9/runs/train/exp5/val_batch0_pred.jpg", width=1000)

# %%
# !cp {HOME}/yolov9/runs/train/exp5/weights/*.pt /content/drive/MyDrive/Workspace/

# %% [markdown]
# ## Validate Custom Model

# %%
# %cd {HOME}/yolov9

# !python val.py \
--img 640 --batch 32 --conf 0.001 --iou 0.7 --device 0 \
--data {dataset.location}/data.yaml \
--weights {HOME}/yolov9/runs/train/exp5/weights/best.pt
# Out:
# /content/yolov9
# Traceback (most recent call last):
#   File "/content/yolov9/val.py", line 388, in <module>
#     opt = parse_opt()
#   File "/content/yolov9/val.py", line 347, in parse_opt
#     opt.data = check_yaml(opt.data)  # check YAML
#   File "/content/yolov9/utils/general.py", line 452, in check_yaml
#     return check_file(file, suffix)
#   File "/content/yolov9/utils/general.py", line 478, in check_file
#     assert len(files), f'File not found: {file}'  # assert file was found
# AssertionError: File not found: {dataset.location}/data.yaml

# %% [markdown]
# ## Inference with Custom Model

# %%
# !python detect.py \
--img 1280 --conf 0.1 --device 0 \
--weights {HOME}/yolov9/runs/train/exp5/weights/best.pt \
--source {dataset.location}/test/images

# %% [markdown]
# **NOTE:** Just like behore, the inference results have been saved in the appropriate directory inside `{HOME}/yolov9/runs/detect/`. Let's examine few of those results.

# %%
import glob

from IPython.display import Image, display

for image_path in glob.glob(f'{HOME}/yolov9/runs/detect/exp3/*.jpg')[:2]:
      display(Image(filename=image_path, width=600))

# %% [markdown]
# ## BONUS: Deploy YOLOv9 Model with Inference

# %% [markdown]
# **NOTE:** To deploy the model and display inference results, we will need two additional packages - [`inference`](https://pypi.org/project/inference) and [`supervision`](https://pypi.org/project/supervision). Let's install and import them!

# %%
# !pip install -q inference supervision

# %%
import cv2
import random
import getpass

import supervision as sv

from inference import get_model

# %matplotlib inline

# %% [markdown]
# **NOTE:** Before using your model in Inference, you first need to upload your weights to Roboflow Universe. Ensure to specify the correct `model_type` - `yolov9`, and that the project version matches the version of the dataset you used for training, denoted by `[1]`. In my case, it's `6`.
#
# ![YOLOv9 Benchmark](https://storage.googleapis.com/com-roboflow-marketing/notebooks/examples/upload-roboflow-model.png)

# %%
version.deploy(model_type="yolov9", model_path=f"{HOME}/yolov9/runs/train/exp")
# Out:
# View the status of your deployment at: https://app.roboflow.com/roboflow-jvuqo/football-players-detection-3zvbc/6
# Share your model with the world at: https://universe.roboflow.com/roboflow-jvuqo/football-players-detection-3zvbc/model/6

# %% [markdown]
# **NOTE:** Now we can download our model anywhere using the assigned `model_id` denoted by `[2]`. In my case `football-players-detection-3zvbc/6`. To download the model you will need your [`ROBOFLOW_API_KEY`](https://docs.roboflow.com/api-reference/authentication).

# %%
ROBOFLOW_API_KEY = getpass.getpass()

model = get_model(model_id="football-players-detection-3zvbc/8", api_key=ROBOFLOW_API_KEY)
# Out:
# ··········

# %% [markdown]
# **NOTE:** Let's pick random image from our test subset and detect objects using newly fine-tuned model.

# %%
image_paths = sv.list_files_with_extensions(
    directory=f"{dataset.location}/test/images",
    extensions=['png', 'jpg', 'jpeg']
)
image_path = random.choice(image_paths)
image = cv2.imread(image_path)

result = model.infer(image, confidence=0.1)[0]
detections = sv.Detections.from_inference(result)

# %% [markdown]
# **NOTE:** Finally, let's use supervision and [annotate](https://supervision.roboflow.com/develop/annotators/) our results.

# %%
label_annotator = sv.LabelAnnotator(text_color=sv.Color.BLACK)
bounding_box_annotator = sv.BoundingBoxAnnotator()

annotated_image = image.copy()
annotated_image = bounding_box_annotator.annotate(scene=annotated_image, detections=detections)
annotated_image = label_annotator.annotate(scene=annotated_image, detections=detections)

sv.plot_image(annotated_image)
